# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Suryansh\Documents\gitsql\Python-for-DE-Advanced\10_Pandas\Dataset\orders.csv')
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df['sales'].sum()
# Out:
# np.float64(15039.599999999999)

# %%
df['sales'].mean()
# Out:
# np.float64(300.792)

# %%
df['sales'].max()
# Out:
# np.float64(3083.4)

# %%
df['sales'].median()
# Out:
# np.float64(74.65)

# %%
df['sales'].count()
# Out:
# np.int64(50)

# %%
df['sales'].min()
# Out:
# np.float64(2.5)

# %%
df['sales'].nunique()
# Out:
# 50

# %%
df['region'].nunique()
# Out:
# 4

# %%
df['region'].unique()
# Out:
# <StringArray>
# ['South', 'West', 'Central', 'East']
# Length: 4, dtype: str

# %%
df['category'].unique()
# Out:
# <StringArray>
# ['Furniture', 'Office Supplies', 'Technology']
# Length: 3, dtype: str

# %%
df.groupby('region')['sales'].sum()
# Out:
# region
# Central    3824.8
# East       3467.7
# South      2085.1
# West       5662.0
# Name: sales, dtype: float64

# %%
df.groupby(['region', 'category'])['sales'].sum()
# Out:
# region   category
# Central  Furniture           935.4
#          Office Supplies    1227.5
#          Technology         1661.9
# East     Furniture          3279.0
#          Office Supplies     121.9
#          Technology           66.8
# South    Furniture          1951.5
#          Office Supplies     133.6
# West     Furniture          2799.7
#          Office Supplies     739.6
#          Technology         2122.7
# Name: sales, dtype: float64

# %%
df.groupby('region')['sales'].agg(['min', 'max', 'sum'])
# Out:
#           min     max     sum
# region
# Central   2.5  1097.5  3824.8
# East      3.3  3083.4  3467.7
# South    15.6   957.6  2085.1
# West      7.3  1706.2  5662.0

# %%
df.groupby('region').agg({'sales': 'sum', 'profit':'mean'})
# Out:
#           sales      profit
# region
# Central  3824.8   -1.294118
# East     3467.7 -163.800000
# South    2085.1  -17.333333
# West     5662.0   43.323529

# %%
df['category'].value_counts()
# Out:
# category
# Office Supplies    28
# Furniture          12
# Technology         10
# Name: count, dtype: int64

# %%
pd.pivot_table(
    df,
    index= 'region', #region is being used here as index
    columns= 'category', #category will be the column names
    values= 'sales', #values are sales that is aggregated into sum
    aggfunc= 'sum',
    fill_value=0 #fill values fills the null value with zero
)
# Out:
# category  Furniture  Office Supplies  Technology
# region
# Central       935.4           1227.5      1661.9
# East         3279.0            121.9        66.8
# South        1951.5            133.6         0.0
# West         2799.7            739.6      2122.7

# %%
df_orders = pd.read_csv(r'C:\Users\Suryansh\Documents\gitsql\Python-for-DE-Advanced\10_Pandas\Dataset\orders.csv')
df_returns = pd.read_csv(r'C:\Users\Suryansh\Documents\gitsql\Python-for-DE-Advanced\10_Pandas\Dataset\returns.csv')

# %%
df_orders
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df_returns
# Out:
#   return_order_id return_reason
# 0  CA-2018-105893   bad quality
# 1  CA-2018-143336    wrong item
# 2  CA-2018-146703    wrong item
# 3  CA-2018-167164         other
# 4  CA-2019-106320   bad quality
# 5  CA-2019-115742         other
# 6  CA-2020-101343   bad quality
# 7  CA-2020-117590    wrong item

# %%
df = pd.merge(left= df_orders, right=df_returns, left_on = 'order_id', right_on= 'return_order_id', how='inner')
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2018-105893  11-11-2018  18-11-2018  Standard Class    PK-19075
# 1   CA-2018-167164  13-05-2018  15-05-2018    Second Class    AG-10270
# 2   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 3   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 4   CA-2018-143336  27-08-2018  01-09-2018    Second Class    ZD-21925
# 5   CA-2019-106320  25-09-2019  30-09-2019  Standard Class    EB-13870
# 6   CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 7   CA-2020-117590  08-12-2020  10-12-2020     First Class    GH-14485
# 8   CA-2020-101343  17-07-2020  22-07-2020  Standard Class    RA-19885
# 9   CA-2018-146703  20-10-2018  25-10-2018    Second Class    PO-18865
# 10  CA-2019-115742  18-04-2019  22-04-2019  Standard Class    DP-13000
#
#      region       product_id         category   sales  quantity  profit  \
# ...

# %%
df = pd.merge(left= df_orders, right= df_returns, left_on = 'order_id', right_on= 'return_order_id', how='left')
df
# Out:
#           order_id  order_date   ship_date       ship_mode customer_id  \
# 0   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 1   CA-2020-152156  08-11-2020  11-11-2020    Second Class    CG-12520
# 2   CA-2020-138688  12-06-2020  16-06-2020    Second Class    DV-13045
# 3   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 4   US-2019-108966  11-10-2019  18-10-2019  Standard Class    SO-20335
# 5   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 6   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 7   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 8   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 9   CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 10  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# 11  CA-2018-115812  09-06-2018  14-06-2018  Standard Class    BH-11710
# ...

# %%
df.groupby('return_reason')['sales'].sum() #tells how much sales loss the company bore
# Out:
# return_reason
# bad quality    1788.4
# other            93.7
# wrong item     1745.2
# Name: sales, dtype: float64

# %%
emp1 = {
    'id': ['UG1','UG2','UG3'],
    'name' : ['Sam', 'Naman', 'Mark'],
    'salary': ['100k', '50k', '80k']
}

emp2 = {
    'id': ['UG4','UG5','UG6'],
    'name' : ['Josh', 'Harry', 'Steve'],
    'salary': ['70k', '50k', '60k']
}

df1 = pd.DataFrame(emp1)
df2 = pd.DataFrame(emp2)

# %%
df1
# Out:
#     id   name salary
# 0  UG1    Sam   100k
# 1  UG2  Naman    50k
# 2  UG3   Mark    80k

# %%
df2
# Out:
#     id   name salary
# 0  UG4   Josh    70k
# 1  UG5  Harry    50k
# 2  UG6  Steve    60k

# %%
df = pd.concat([df1, df2])
df.reset_index(drop=True, inplace=True) 
df
# Out:
#     id   name salary
# 0  UG1    Sam   100k
# 1  UG2  Naman    50k
# 2  UG3   Mark    80k
# 3  UG4   Josh    70k
# 4  UG5  Harry    50k
# 5  UG6  Steve    60k

# %%
df = pd.concat([df1, df2], ignore_index=True)
df
# Out:
#     id   name salary
# 0  UG1    Sam   100k
# 1  UG2  Naman    50k
# 2  UG3   Mark    80k
# 3  UG4   Josh    70k
# 4  UG5  Harry    50k
# 5  UG6  Steve    60k
